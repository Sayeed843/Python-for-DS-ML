# %% [markdown]
# # Python Crash Course- Part-1

# %%
1
# Out:
# 1

# %%
1.0
# Out:
# 1.0

# %%
1+1
# Out:
# 2

# %%
2*4
# Out:
# 8

# %%
4/2
# Out:
# 2.0

# %%
2**4
# Out:
# 16

# %%
4%2
# Out:
# 0

# %%
5%2
# Out:
# 1

# %%
2+3*5+5
# Out:
# 22

# %%
(2+3)*(5+5)
# Out:
# 50

# %%
var = 2

# %%
x= 2
y= 5

# %%
x+y
# Out:
# 7

# %%
y=10

# %%
x+y
# Out:
# 12

# %%
x = x+x

# %%
x
# Out:
# 4

# %%
x =+ x

# %%
x
# Out:
# 4

# %%
"My Life is great!"
# Out:
# 'My Life is great!'

# %%
"My Life is great!"[0]
# Out:
# 'M'

# %%
"My Life is great!"[2]
# Out:
# ' '

# %%
"My Life is great!"[2]='c'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 "My Life is great!"[2]='c'
#
# TypeError: 'str' object does not support item assignment

# %%
myStr = "My Life is great!"

# %%
myStr[3]
# Out:
# 'L'

# %%
myStr[2]='c'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 myStr[2]='c'
#
# TypeError: 'str' object does not support item assignment

# %%
myStr="We learn Python!"

# %%
myStr
# Out:
# 'We learn Python!'

# %%
len(myStr)
# Out:
# 16

# %%
myStr[16]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 myStr[16]
#
# IndexError: string index out of range

# %%
myStr[15]
# Out:
# '!'

# %%
myStr[-1]
# Out:
# '!'

# %%
myStr[-2]
# Out:
# 'n'

# %%
myStr[-5]
# Out:
# 't'

# %%
myStr[0:2]
# Out:
# 'We'

# %%
myStr[4:9]
# Out:
# 'earn '

# %%
myStr[3:7]
# Out:
# 'lear'

# %%
myStr[3:8]  #index, position
# Out:
# 'learn'

# %%
s = 'abcdefghklmnopqrstuvwxyz'

# %%
s[0:5]
# Out:
# 'abcde'

# %%
s[0:5:2]
# Out:
# 'ace'

# %%
s[::2]
# Out:
# 'acegkmoqsuwy'

# %%
s[::3] #index , index+1, step
# Out:
# 'adglorux'

# %%
s[6::]
# Out:
# 'ghklmnopqrstuvwxyz'

# %%
s[::-1]
# Out:
# 'zyxwvutsrqponmlkhgfedcba'

# %%
num = 12
name = 'Sam'

# %%
"My name is {} and number is {}".format(name, num)
# Out:
# 'My name is Sam and number is 12'

# %%
print("My name is {} and number is {}".format(name, num))
# Out:
# My name is Sam and number is 12

# %%
"My name is {one} and number is {two}".format(one=name, two=num)
# Out:
# 'My name is Sam and number is 12'

# %%
"My name is {n1} and number is {n2}".format(n1="Masud", n2=54)
# Out:
# 'My name is Masud and number is 54'

# %%
one
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 one
#
# NameError: name 'one' is not defined

# %%
[1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %%
[1,2,3,4,80.0]
# Out:
# [1, 2, 3, 4, 80.0]

# %%
[1,2,3,4,80.0,'myname']
# Out:
# [1, 2, 3, 4, 80.0, 'myname']

# %%
[1,2,3,4,80.0,'myname',[5,4,3]] #nested list
# Out:
# [1, 2, 3, 4, 80.0, 'myname', [5, 4, 3]]

# %%
mylist = [10,20,30,40,50]

# %%
mylist[0]
# Out:
# 10

# %%
mylist[3]
# Out:
# 40

# %%
mylist[0] = 100

# %%
mylist
# Out:
# [100, 20, 30, 40, 50]

# %%
mylist[0:3]
# Out:
# [100, 20, 30]

# %%
mylist[0:3:2]
# Out:
# [100, 30]

# %%
mylist[::-1]
# Out:
# [50, 40, 30, 20, 100]

# %%
mylist
# Out:
# [100, 20, 30, 40, 50]

# %%
mylist.append(100)

# %%
mylist
# Out:
# [10, 20, 30, 40, 50, 100]

# %%
mylist
# Out:
# [10, 20, 30, 40, 50, 100]

# %%
delete_value = mylist.pop()

# %%
delete_value
# Out:
# 100

# %%
mylist.remove(20)

# %%
mylist.append(50)

# %%
mylist
# Out:
# [10, 30, 40, 50, 50]

# %%
mylist.remove(50)

# %%
mylist
# Out:
# [10, 30, 40, 50]

# %%
nested_list = [10,20,30,40,[50,60,['target']]]

# %%
nested_list
# Out:
# [10, 20, 30, 40, [50, 60, ['target']]]

# %%
nested_list[4]
# Out:
# [50, 60, ['target']]

# %%
nested_list[4][0]
# Out:
# 50

# %%
nested_list[4][2]
# Out:
# ['target']

# %%
nested_list[4][2][0]
# Out:
# 'target'

# %%
nested_list[4][2][0][4]
# Out:
# 'e'

# %%
nested_list[4][2][0][::-1]
# Out:
# 'tegrat'
