# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
my_data = [10,20,30]
arr = np.array(my_data)
d = {'a':10, 'b':20, 'c':30}

# %%
pd.Series(data = my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data = my_data, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data=[sum, print, len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
ser1 = pd.Series(data=[1,2,3,4],index=['USA', 'GERMANY','USSR', 'JAPAN'])

# %%
ser1
# Out:
# USA        1
# GERMANY    2
# USSR       3
# JAPAN      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4],['USA','GERMANY', 'ITALY','JAPAN'])

# %%
ser2
# Out:
# USA        1
# GERMANY    2
# ITALY      5
# JAPAN      4
# dtype: int64

# %%
ser1['USA']
# Out:
# 1

# %%
ser1['JAPAN']
# Out:
# 4

# %%
ser2['ITALY']
# Out:
# 5

# %%
ser1+ser2
# Out:
# GERMANY    4.0
# ITALY      NaN
# JAPAN      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %% [markdown]
# ## Pandas DataFrame Part-1

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(data =randn(5,4), index=['A', 'B','C','D','E'], columns=['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W']
# Out:
# A   -0.711281
# B   -0.762516
# C   -0.705479
# D   -0.534714
# E    1.098538
# Name: W, dtype: float64

# %%
df['X']
# Out:
# A    0.004785
# B    0.743237
# C   -0.103857
# D   -0.817018
# E   -0.118228
# Name: X, dtype: float64

# %%
df.X   # not a good practice!
# Out:
# A    0.628133
# B   -0.319318
# C    0.740122
# D   -0.758872
# E    1.978757
# Name: X, dtype: float64

# %%
df[['W', 'Y']]
# Out:
#           W         Y
# A -0.711281 -0.301801
# B -0.762516 -2.077949
# C -0.705479  0.209148
# D -0.534714 -0.172537
# E  1.098538  0.972034

# %%
df[['W','Z']]
# Out:
#           W         Z
# A -0.711281  0.672053
# B -0.762516  1.203745
# C -0.705479  0.488712
# D -0.534714  0.270206
# E  1.098538  0.344192

# %%
df['new']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/my-venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df['new']
#
# ...

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.711281  0.004785 -0.301801  0.672053 -1.013082
# B -0.762516  0.743237 -2.077949  1.203745 -2.840464
# C -0.705479 -0.103857  0.209148  0.488712 -0.496332
# D -0.534714 -0.817018 -0.172537  0.270206 -0.707251
# E  1.098538 -0.118228  0.972034  0.344192  2.070572

# %%
df.drop('new', axis=1)  # Axis 0 means row and 1 means column
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('new', axis=1, inplace=True) # Parmenently delete

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.drop('A', axis=0)  # Axis 0 means row and 1 means column
# Out:
#           W         X         Y         Z
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.shape #axis 0=Row-5 rows and axis 1= columns 4
# Out:
# (5, 4)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.loc['A'] # loc means location
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.loc['C']
# Out:
# W   -2.018168
# X    0.740122
# Y    0.528813
# Z   -0.589001
# Name: C, dtype: float64

# %%
df.iloc[3] # iloc means index location
# Out:
# W    0.188695
# X   -0.758872
# Y   -0.933237
# Z    0.955057
# Name: D, dtype: float64

# %%
df.loc['B']
# Out:
# W    0.651118
# X   -0.319318
# Y   -0.848077
# Z    0.605965
# Name: B, dtype: float64

# %%
df.loc['B','Y'] #  single data grap by row and column
# Out:
# -0.8480769834036315

# %%
df.loc[['A','B']]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965

# %%
df.loc[['A','B'], ['W','Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %% [markdown]
# ## Pandas's DataFrames - Part-2

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.711281  0.004785 -0.301801  0.672053 -1.013082
# B -0.762516  0.743237 -2.077949  1.203745 -2.840464
# C -0.705479 -0.103857  0.209148  0.488712 -0.496332
# D -0.534714 -0.817018 -0.172537  0.270206 -0.707251
# E  1.098538 -0.118228  0.972034  0.344192  2.070572

# %%
df.drop('new', axis=1, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df>0
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W'] < 0
# Out:
# A    False
# B    False
# C     True
# D    False
# E    False
# Name: W, dtype: bool

# %%
df[df['W'] < 0]
# Out:
#           W         X         Y         Z
# C -2.018168  0.740122  0.528813 -0.589001

# %%
df['Z'] < 0
# Out:
# A    False
# B    False
# C     True
# D    False
# E    False
# Name: Z, dtype: bool

# %%
df[df['Z'] < 0]
# Out:
#           W         X         Y         Z
# C -2.018168  0.740122  0.528813 -0.589001

# %%
out = df[df['W']>0]

# %%
out
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
out['W']
# Out:
# A    2.706850
# B    0.651118
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
out[['X','Z']]
# Out:
#           X         Z
# A  0.628133  0.503826
# B -0.319318  0.605965
# D -0.758872  0.955057
# E  1.978757  0.683509

# %%
out.loc['A']
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
out.loc[['A','D']]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
out.loc['C']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/my-venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'C'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 out.loc['C']
#
# ...

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W'] > 2
# Out:
# A     True
# B    False
# C    False
# D    False
# E    False
# Name: W, dtype: bool

# %%
df[df['W'] > 2]
# Out:
#          W         X         Y         Z
# A  2.70685  0.628133  0.907969  0.503826

# %%
df['Z'] > 0.5
# Out:
# A     True
# B     True
# C    False
# D     True
# E     True
# Name: Z, dtype: bool

# %%
df['W'] > 2 and df['Z'] > 0.5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13365/2359711540.py in ?()
# ----> 1 df['W'] > 2 and df['Z'] > 0.5
#
# ~/Documents/my-venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
(df['W'] > 2) & (df['Z'] > 0.5)
# Out:
# A     True
# B    False
# C    False
# D    False
# E    False
# dtype: bool

# %%
df[(df['W'] > 2) & (df['Z'] > 0.5)]
# Out:
#          W         X         Y         Z
# A  2.70685  0.628133  0.907969  0.503826

# %%
df[(df['W'] > 2) | (df['Z'] > 0.5)]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index() #For peraanent, use inplace = True
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
newind = 'CA NY WY OR CO'.split()

# %%
newind
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['states'] = newind

# %%
df
# Out:
#           W         X         Y         Z states
# A  2.706850  0.628133  0.907969  0.503826     CA
# B  0.651118 -0.319318 -0.848077  0.605965     NY
# C -2.018168  0.740122  0.528813 -0.589001     WY
# D  0.188695 -0.758872 -0.933237  0.955057     OR
# E  0.190794  1.978757  2.605967  0.683509     CO

# %%
df.set_index('states') #Forpermanent, use inplace = True
# Out:
#                W         X         Y         Z
# states
# CA      2.706850  0.628133  0.907969  0.503826
# NY      0.651118 -0.319318 -0.848077  0.605965
# WY     -2.018168  0.740122  0.528813 -0.589001
# OR      0.188695 -0.758872 -0.933237  0.955057
# CO      0.190794  1.978757  2.605967  0.683509

# %%
df.set_index('states', inplace=True)

# %%
df
# Out:
#                W         X         Y         Z
# states
# CA      2.706850  0.628133  0.907969  0.503826
# NY      0.651118 -0.319318 -0.848077  0.605965
# WY     -2.018168  0.740122  0.528813 -0.589001
# OR      0.188695 -0.758872 -0.933237  0.955057
# CO      0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   states         W         X         Y         Z
# 0     CA  2.706850  0.628133  0.907969  0.503826
# 1     NY  0.651118 -0.319318 -0.848077  0.605965
# 2     WY -2.018168  0.740122  0.528813 -0.589001
# 3     OR  0.188695 -0.758872 -0.933237  0.955057
# 4     CO  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# ## Pandas's DataFrame Part-3

# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
outside = ['G1', 'G1', 'G1', 'G2', 'G2', 'G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside, inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
list(zip(outside, inside))
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(data = randn(6,2), index = hier_index, columns=['A', 'B'])

# %%
df
# Out:
#              A         B
# G1 1  1.025984 -0.156598
#    2 -0.031579  0.649826
#    3  2.154846 -0.610259
# G2 1 -0.755325 -0.346419
#    2  0.147027 -0.479448
#    3  0.558769  1.024810

# %%
df.loc['G1']
# Out:
#           A         B
# 1 -0.925874  1.862864
# 2 -1.133817  0.610478
# 3  0.386030  2.084019

# %%
df.loc['G2']
# Out:
#           A         B
# 1 -0.376519  0.230336
# 2  0.681209  1.035125
# 3 -0.031160  1.939932

# %%
df.loc['G1'].loc[2] # Grap the row
# Out:
# A   -1.133817
# B    0.610478
# Name: 2, dtype: float64

# %%
df.loc['G1']['B']  # Grap the column'
# Out:
# 1    1.862864
# 2    0.610478
# 3    2.084019
# Name: B, dtype: float64

# %%
df.loc['G1'].loc[2]['B']
# Out:
# 0.6104779075384634

# %%
# xs

# %%
df
# Out:
#              A         B
# G1 1 -0.925874  1.862864
#    2 -1.133817  0.610478
#    3  0.386030  2.084019
# G2 1 -0.376519  0.230336
#    2  0.681209  1.035125
#    3 -0.031160  1.939932

# %%
df.xs('G1')
# Out:
#           A         B
# 1 -0.925874  1.862864
# 2 -1.133817  0.610478
# 3  0.386030  2.084019

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Group', 'Num']

# %%
df
# Out:
#                   A         B
# Group Num
# G1    1   -0.925874  1.862864
#       2   -1.133817  0.610478
#       3    0.386030  2.084019
# G2    1   -0.376519  0.230336
#       2    0.681209  1.035125
#       3   -0.031160  1.939932

# %%
df
# Out:
#                   A         B
# Group Num
# G1    1   -0.925874  1.862864
#       2   -1.133817  0.610478
#       3    0.386030  2.084019
# G2    1   -0.376519  0.230336
#       2    0.681209  1.035125
#       3   -0.031160  1.939932

# %%
df.xs('G1')
# Out:
#             A         B
# Num
# 1   -0.925874  1.862864
# 2   -1.133817  0.610478
# 3    0.386030  2.084019

# %%
df
# Out:
#                   A         B
# Group Num
# G1    1   -0.925874  1.862864
#       2   -1.133817  0.610478
#       3    0.386030  2.084019
# G2    1   -0.376519  0.230336
#       2    0.681209  1.035125
#       3   -0.031160  1.939932

# %%
df.xs(1, level='Group')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/my-venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df.xs(1, level='Group')
#
# ...

# %%
df.xs(3, level='Num')
# Out:
#              A         B
# Group
# G1     0.38603  2.084019
# G2    -0.03116  1.939932
